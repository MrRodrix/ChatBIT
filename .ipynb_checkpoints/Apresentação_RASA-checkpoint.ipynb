# %% [markdown]
# #Apresentação Cesar
# ##ChatBIT: MODELO DEFAULT
# ####(Usa 3 algoritmos e escolhe o melhor para aquela situação)

# %% [markdown]
# ###1. Treinando o robô

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import rasa

# %%
config = "config.yml"
training_files = "data/"
domain = "domain.yml"
output = "models/"
endpoints = "endpoints.yml"

# %%
modelo_default = rasa.train("domain.yml","config.yml", ["data/"], "models/")
# Out:
# Core stories/configuration did not change. No need to retrain Core model.
# Training NLU model...
# C:\Users\Rodrigues\AppData\Roaming\Python\Python36\site-packages\rasa\nlu\classifiers\diet_classifier.py:595: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   for tag_name, tag_ids in tag_name_to_tag_ids.items()
# ...

# %% [markdown]
# ###2. Conversando com o robô

# %% [markdown]
# ###3. Validando o robô

# %%
stories_directory, nlu_data_directory = rasa.data.get_core_nlu_directories(training_files)

# %%
modelo_rlc = 'models/modeloRLC.tar.gz'
modelo_rl = 'models/modeloRL.tar.gz'
modelo_lc = 'models/modeloLC.tar.gz'
modelo_rc = 'models/modeloRC.tar.gz'
modelo_l = 'models/modeloL.tar.gz'
modelo_c = 'models/modeloC.tar.gz'
# Out:
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 301/301 [00:01<00:00, 162.00it/s]

# %%
# Out:
# NoneType

# %%
import os
def visualizar(modelo):
    if os.path.isfile("errors.json"):
        print("NLU Errors:")
        print(open("errors.json").read())
    else:
        print("No NLU errors.")

    if os.path.isdir("results"):
        print("\n")
        print("Results INTENTS:")
        print(open("results/intent_report"+modelo+".json").read())
        print("\n\n\n\nResults CLASSIFIER:")
        print(open("results/DIETClassifier_report"+modelo+".json").read())
    pass

# %%
visualizar('l')
# Out:
# No NLU errors.
#
#
# Results INTENTS:
# {
#   "dispensar_estagio": {
#     "precision": 0.0,
#     "recall": 0.0,
#     "f1-score": 0.0,
#     "support": 10,
#     "confused_with": {
#       "prereqs": 4,
#       "info_estagio": 4,
#       "empresa_ch_complementar": 2
#     }
#   },
#   "saber_criador": {
#     "precision": 0.0,
#     "recall": 0.0,
#     "f1-score": 0.0,
#     "support": 10,
#     "confused_with": {
#       "prereqs": 10
#     }
#   },
#   "info_estagio": {
#     "precision": 0.34615384615384615,
#     "recall": 0.6,
#     "f1-score": 0.43902439024390244,
#     "support": 15,
#     "confused_with": {
#       "prereqs": 6
#     }
#   },
#   "horas_necessarias": {
#     "precision": 0.0,
#     "recall": 0.0,
#     "f1-score": 0.0,
#     "support": 10,
#     "confused_with": {
#       "prereqs": 4,
#       "duvida_carga_horaria_complementar3": 4,
#       "empresa_ch_complementar": 2
#     }
#   },
#   "recusar": {
#     "precision": 0.0,
#     "recall": 0.0,
# ...

# %%
visualizar('c')
# Out:
# No NLU errors.
#
#
# Results INTENTS:
# {
#   "dispensar_estagio": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "saber_criador": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "info_estagio": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 15,
#     "confused_with": {}
#   },
#   "horas_necessarias": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "recusar": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 17,
#     "confused_with": {}
#   },
#   "empresa_ch_complementar": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 7,
#     "confused_with": {}
#   },
#   "duvida_carga_horaria_complementar3": {
#     "precision": 1.0,
# ...

# %%
visualizar('rc')
# Out:
# No NLU errors.
#
#
# Results INTENTS:
# {
#   "dispensar_estagio": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "saber_criador": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "info_estagio": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 15,
#     "confused_with": {}
#   },
#   "horas_necessarias": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "recusar": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 17,
#     "confused_with": {}
#   },
#   "empresa_ch_complementar": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 7,
#     "confused_with": {}
#   },
#   "duvida_carga_horaria_complementar3": {
#     "precision": 1.0,
# ...

# %%
visualizar('rlc')
# Out:
# No NLU errors.
#
#
# Results INTENTS:
# {
#   "dispensar_estagio": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "saber_criador": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "info_estagio": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 15,
#     "confused_with": {}
#   },
#   "horas_necessarias": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "recusar": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 17,
#     "confused_with": {}
#   },
#   "empresa_ch_complementar": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 7,
#     "confused_with": {}
#   },
#   "duvida_carga_horaria_complementar3": {
#     "precision": 1.0,
# ...

# %%
visualizar('lc')
# Out:
# No NLU errors.
#
#
# Results INTENTS:
# {
#   "dispensar_estagio": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "saber_criador": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "info_estagio": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 15,
#     "confused_with": {}
#   },
#   "horas_necessarias": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 10,
#     "confused_with": {}
#   },
#   "recusar": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 17,
#     "confused_with": {}
#   },
#   "empresa_ch_complementar": {
#     "precision": 1.0,
#     "recall": 1.0,
#     "f1-score": 1.0,
#     "support": 7,
#     "confused_with": {}
#   },
#   "duvida_carga_horaria_complementar3": {
#     "precision": 1.0,
# ...
